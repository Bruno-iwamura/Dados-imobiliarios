# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#conexão postgres

engine_pg = create_engine('postgresql://postgres:PostgreeMain@localhost:5432/bruno_db_alura')

df = pd.read_sql('SELECT * FROM imoveis_brasil',engine_pg)

#conexao sqlserver

connection_string = (
    "mssql+pyodbc://DESKTOP-327NN27\\SQLEXPRESS/bruno_db_sqlserver"
    "?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes&Encrypt=no"
)
engine_sqlserver = create_engine(connection_string)

df.to_sql('imoveis_brasil', engine_sqlserver, if_exists='replace', index=False)

print("Migração concluída com sucesso.")
# Out:
# c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\sql.py:1648: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
# 🚀 Migração concluída com sucesso!
